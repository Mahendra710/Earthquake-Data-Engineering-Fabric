# %% [markdown]
# # **Bronze Layer Processing**

# %%
from datetime import date, timedelta
# Out:
# StatementMeta(, 7cbec038-51f7-4f4d-8896-d2ccf8906959, 5, Finished, Available, Finished)

# %%
start_date= date.today()-timedelta(7)
end_date= date.today()-timedelta(1)
# Out:
# StatementMeta(, 7cbec038-51f7-4f4d-8896-d2ccf8906959, 6, Finished, Available, Finished)

# %%
import requests
import json
# Out:
# StatementMeta(, 7cbec038-51f7-4f4d-8896-d2ccf8906959, 7, Finished, Available, Finished)

# %%
url= f"https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime={start_date}&endtime={end_date}"
response= requests.get(url)
# Out:
# StatementMeta(, 7cbec038-51f7-4f4d-8896-d2ccf8906959, 8, Finished, Available, Finished)
# 200

# %%
if response.status_code==200:
    data= response.json()
    data=data['features']
    file_path= f"/lakehouse/default/Files/{start_date}_earthquake_data.json"
    with open(file_path,'w') as file:
        json.dump(data,file,indent=4)
    print(f"Data Successfully Saved to {file_path}")
else:
    print("Failed to fetch data.Status Code:", response.status_code)
# Out:
# StatementMeta(, 7cbec038-51f7-4f4d-8896-d2ccf8906959, 19, Finished, Available, Finished)
# Data Successfully Saved to /lakehouse/default/Files/2025-05-22_earthquake_data.json

# %%
print(data)
# Out:
# StatementMeta(, 7cbec038-51f7-4f4d-8896-d2ccf8906959, 12, Finished, Available, Finished)
# [{'type': 'Feature', 'properties': {'mag': 1.2, 'place': '12 km ENE of Borrego Springs, CA', 'time': 1748389954110, 'updated': 1748439275799, 'tz': None, 'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40978031', 'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40978031&format=geojson', 'felt': None, 'cdi': None, 'mmi': None, 'alert': None, 'status': 'reviewed', 'tsunami': 0, 'sig': 22, 'net': 'ci', 'code': '40978031', 'ids': ',ci40978031,', 'sources': ',ci,', 'types': ',nearby-cities,origin,phase-data,scitech-link,', 'nst': 58, 'dmin': 0.07751, 'rms': 0.23, 'gap': 23, 'magType': 'ml', 'type': 'earthquake', 'title': 'M 1.2 - 12 km ENE of Borrego Springs, CA'}, 'geometry': {'type': 'Point', 'coordinates': [-116.2538333, 33.3003333, 2.9]}, 'id': 'ci40978031'}, {'type': 'Feature', 'properties': {'mag': 1.65, 'place': '3 km SW of Yorba Linda, CA', 'time': 1748389269490, 'updated': 1748473485650, 'tz': None, 'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40978015', 'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40978015&format=geojson', 'felt': None, 'cdi': None, 'mmi': None, 'alert': None, 'status': 'reviewed', 'tsunami': 0, 'sig': 42, 'net': 'ci', 'code': '40978015', 'ids': ',ci40978015,', 'sources': ',ci,', 'types': ',nearby-cities,origin,phase-data,scitech-link,', 'nst': 49, 'dmin': 0.02245, 'rms': 0.2, 'gap': 71, 'magType': 'ml', 'type': 'earthquake', 'title': 'M 1.7 - 3 km SW of Yorba Linda, CA'}, 'geometry': {'type': 'Point', 'coordinates': [-117.834, 33.864, 5.16]}, 'id': 'ci40978015'}, {'type': 'Feature', 'properties': {'mag': 1.6, 'place': '5 km NW of Boron, CA', 'time': 1748388888460, 'updated': 1748389101670, 'tz': None, 'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40978007', 'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40978007&format=geojson', 'felt': None, 'cdi': None, 'mmi': None, 'alert': None, 'status': 'automatic', 'tsunami': 0, 'sig': 39, 'net': 'ci', 'code': '40978007', 'ids': ',ci40978007,', 'sources': ',ci,', 'types': ',nearby-cities,origin,phase-data,scitech-link,', 'nst': 40, 'dmin': 0.0985, 'rms': 0.18, 'gap': 39, 'magType': 'ml', 'type': 'earthquake', 'title': 'M 1.6 - 5 km NW of Boron, CA'}, 'geometry': {'type': 'Point', 'coordinates': [-117.6848333, 35.0326667, -0.74]}, 'id': 'ci40978007'}, {'type': 'Feature', 'properties': {'mag': 0.79, 'place': '6 km NW of The Geysers, CA', 'time': 1748388099890, 'updated': 1748389937959, 'tz': None, 'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75187411', 'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75187411&format=geojson', 'felt': None, 'cdi': None, 'mmi': None, 'alert': None, 'status': 'automatic', 'tsunami': 0, 'sig': 10, 'net': 'nc', 'code': '75187411', 'ids': ',nc75187411,', 'sources': ',nc,', 'types': ',nearby-cities,origin,phase-data,scitech-link,', 'nst': 9, 'dmin': 0.014, 'rms': 0.02, 'gap': 83, 'magType': 'md', 'type': 'earthquake', 'title': 'M 0.8 - 6 km NW of The Geysers, CA'}, 'geometry': {'type': 'Point', 'coordinates': [-122.815170288086, 38.7986679077148, 3.48000001907349]}, 'id': 'nc75187411'}, {'type': 'Feature', 'properties': {'mag': 0.9, 'place': '33 km WSW of Ackerly, Texas', 'time': 1748387927615, 'updated': 1748388580183, 'tz': None, 'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2025kint', 'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2025kint&format=geojson', 'felt': None, 'cdi': None, 'mmi': None, 'alert': None, 'status': 'automatic', 'tsunami': 0, 'sig': 12, 'net': 'tx', 'code': '2025kint', 'ids': ',tx2025kint,', 'sources': ',tx,', 'types': ',origin,phase-data,', 'nst': 18, 'dmin': 0.1, 'rms': 0.4, 'gap': 80, 'magType': 'ml', 'type': 'earthquake', 'title': 'M 0.9 - 33 km WSW of Ackerly, Texas'}, 'geometry': {'type': 'Point', 'coordinates': [-102.041, 32.403, 5.5979]}, 'id': 'tx2025kint'}, {'type': 'Feature', 'properties': {'mag': 2.22, 'place': '3 km NE of L ...
